# %%
from lintcode import (
    TreeNode,
)

"""
Definition of TreeNode:
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left, self.right = None, None
"""

class Solution:
    """
    @param root: The root of binary tree.
    @return: True if this Binary tree is Balanced, or false.
    """
    def is_balanced(self, root: TreeNode) -> bool:
        is_balanced, _ = self.divideConquer(root)
        return is_balanced
    
    def divideConquer(self, root):
        if not root:
            return True, 0
        is_left_balanced, left_depth = self.divideConquer(root.left)
        is_right_balanced, right_depth = self.divideConquer(root.right)
        root_depth = max(left_depth, right_depth) + 1
        if not is_left_balanced or not is_right_balanced:
            return False, root_depth
        if abs(left_depth - right_depth) > 1:
            return False, root_depth
        return True, root_depth
    """
    # Not a good implementation
    def is_balanced(self, root: TreeNode) -> bool:
        if not root:
            return True
        left_depth = self.depth(root.left)
        right_depth = self.depth(root.right)
        if not self.is_balanced(root.left):
            return False
        if not self.is_balanced(root.right):
            return False
        return abs(left_depth - right_depth) <= 1


    def depth(self, root):
        if not root:
            return 0
        left_depth = self.depth(root.left)
        right_depth = self.depth(root.right)
        return max(left_depth, right_depth) + 1
    """
